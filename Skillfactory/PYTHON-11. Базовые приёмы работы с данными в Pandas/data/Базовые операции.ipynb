# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970  \
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
# На протяжении всего модуля мы будем производить 
# множество тренировочных преобразований с нашей таблицей.
# Поэтому, чтобы не переопределять переменную melb_data и 
# тем самым не повредить первоначальный DataFrame, 
# создадим копию melb_df с помощью метода copy():

melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970  \
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
# Удалим столбцы index и Coordinates из таблицы с помощью метода drop().
# Основные параметры метода drop()

# labels — порядковые номера или имена столбцов, которые подлежат удалению; если их несколько, то передаётся список;

# axis — ось совершения операции, 
#           axis=0 — удаляются строки,
#           axis=1 — удаляются столбцы;

# inplace — если параметр выставлен на 
#           True, происходит замена изначального DataFrame на новый,
#           при этом метод ничего не возвращает;
#           если на 
#           False — возвращается копия DataFrame, 
#           из которой удалены указанные строки (столбцы),
#           при этом первоначальный DataFrame не изменяется;
#           по умолчанию параметр равен False.

# Выведем первые пять строк таблицы и убедимся, что всё прошло успешно.

melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea
# 0  3/12/2016       2.5      3067  ...         1    1     202.0         126.0  \
# 1  4/02/2016       2.5      3067  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...         2    1      94.0         126.0
# 4  4/06/2016       2.5      3067  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname
# ...

# %%
# Альтернативный вариант:

melb_df.drop(['index','Coordinates'],axis=1,inplace=True)
melb_df.head()

# %%
# МАТЕМАТИЧЕСКИЕ ОПЕРАЦИИ СО СТОЛБЦАМИ

#→ Pandas поддерживает базовые математические операции между столбцами:
# столбцы можно 
# складывать,
# вычитать,
# умножать,
# делить между собой,
# а также возводить в степень.
# С помощью таких операций мы можем создавать новые признаки
# или производить преобразования над старыми.

# Например, давайте создадим переменную total_rooms,
# в которой будем хранить общее количество комнат в здании.
# Для этого выполним сложение столбцов с количеством
# комнат, ванн и спален:

total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms)
# Out:
# 0         5
# 1         5
# 2         8
# 3         8
# 4         8
#          ..
# 13575    10
# 13576     8
# 13577     8
# 13578     9
# 13579     9
# Length: 13580, dtype: int64

# %%
# А теперь введём признак MeanRoomsSquare,
# который соответствует средней площади одной комнаты для каждого объекта.
# Для этого разделим площадь здания
# на полученное ранее общее количество комнат:

melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsSquare'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64

# %%
# Можно ввести ещё один интересный признак —
# AreaRatio,
# коэффициент соотношения площади здания (BuildingArea)
# и площади участка (Landsize).
# Для этого разницу двух площадей поделим на их сумму:

diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
display(melb_df.head())
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt
# 0  3/12/2016       2.5      3067  ...     202.0         126.0       1970  \
# 1  4/02/2016       2.5      3067  ...     156.0          79.0       1900
# 2  4/03/2017       2.5      3067  ...     134.0         150.0       1900
# 3  4/03/2017       2.5      3067  ...      94.0         126.0       1970
# 4  4/06/2016       2.5      3067  ...     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
# Цена за квадратный метр

melb_df['PriceForSqureMetr'] = melb_df['Price'] / melb_df['BuildingArea'] + melb_df['Landsize']
display(melb_df['PriceForSqureMetr'])
# Out:
# 0        11948.031746
# 1        13257.265823
# 2         9900.666667
# 3         6840.031746
# 4        11387.605634
#              ...
# 13575    10532.952381
# 13576     8084.879699
# 13577     9721.714286
# 13578    16789.566879
# 13579    11835.214286
# Name: PriceForSqureMetr, Length: 13580, dtype: float64

# %%
customer_df = pd.DataFrame({
            'number': [0, 1, 2, 3, 4],
            'cust_id': [128, 1201, 9832, 4392, 7472],
            'cust_age': [13, 21, 19, 21, 60],
            'cust_sale': [0, 0, 0.2, 0.15, 0.3],
            'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
            'cust_order': [1400, 14142, 900, 1240, 8430]
        })
#cols_to_delete = ['number','cust_id']

def delete_columns(df, col=[]):
    if col not in df.columns: return None
    else:
        df.drop(col, axis=1)
    return df

display(delete_columns(customer_df, ['number','cust_id']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 17
#      14         df.drop(col, axis=1)
#      15     return df
# ---> 17 display(delete_columns(customer_df, ['number','cust_id']))
#
# Cell In[9], line 12, in delete_columns(df, col)
#      11 def delete_columns(df, col=[]):
# ---> 12     if col not in df.columns: return None
#      13     else:
#      14         df.drop(col, axis=1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5143, in Index.__contains__(self, key)
#    5108 def __contains__(self, key: Any) -> bool:
#    5109     """
#    5110     Return a boolean indicating whether the provided key is in the index.
#    5111
#    (...)
#    5141     False
#    5142     """
# -> 5143     hash(key)
#    5144     try:
#    5145         return key in self._engine
#
# TypeError: unhashable type: 'list'

# %%
def delete_columns(df, col=[]):
    columns_list = list(df.columns)
    for each in col:
        if col in columns_list:
            return df.drop(col, axis=1)   
        else:
            return None
    return df

print(delete_columns(customer_df, ['number','cust_id']))
# Out:
# None

# %%
def delete_columns(df, col=[]):
    for cc in col:                  # цикл по списку, переданному в качестве аргумента функции
        if cc not in df.columns:    # если элемента списка нет в названиях столбцов
            return None             # возвращаем None
    return df.drop(col, axis=1)     # во всех остальных удаляем столбцы из списка и возвращаем новый DataFrame

print(delete_columns(customer_df, ['number','cust_id']))
# Out:
#    cust_age  cust_sale  cust_year_birth  cust_order
# 0        13       0.00             2008        1400
# 1        21       0.00             2000       14142
# 2        19       0.20             2002         900
# 3        21       0.15             2000        1240
# 4        60       0.30             1961        8430

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

print(round((countries_df['population']*10**6 / countries_df['square']).mean(),2))
# Out:
# 84.93
